# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# First, we need to keep in mind that the performance of the care means clustering algorithm depends on the highly efficient clusters that it forms.
#
# Hence, choosing the optimal number of clusters is a big critical task.
#
# There are some different ways to find the optimal number of clusters, but here we are discussing the most appropriate method to find the number of clusters or value of care.
#
# The method given below is the elbow method.
#
# The elbow method is one of the most popular ways to find the optimal number of clusters.
# As you can see in the formula below, we have the sum of the distances between each data point and it centroid squared.
# And all of this is within cluster one.
# Then we add to it the sum of the distances between each data point and its centroid squared.
# And it's all within cluster two.
# And the same goes for the third term.
# It is the sum of the distance squared within close to three.
# Now, to measure the distance between the data points and the centroid, we can use any methods such as the.
# Euclidean distance or the Manhattan distance.

# %% [markdown]
# ![image.png](attachment:image.png)
